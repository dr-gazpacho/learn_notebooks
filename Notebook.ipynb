# %% [markdown]
# ## A header on top of data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

x = [100, 3, 5, 77, 34, 99, 95, 96, 33, 65, 75, 83, 85, 87, 1, 12, 13, 17, 99, 100, 100]
num_bins = 5
plt.hist(x, num_bins)
plt.show()

# %% [markdown]
# ### A section of pure python

# %%
msg="hello world"
print(msg)
# Out:
# hello world
